# %% [markdown]
# # Temperature Forecast Prediction
#
# ## Problem Statement:
#
# This data is for the purpose of bias correction of next-day maximum and minimum air temperatures forecast of the LDAPS model operated by the Korea Meteorological Administration over Seoul, South Korea. This data consists of summer data from 2013 to 2017. The input data is largely composed of the LDAPS model's next-day forecast data, in-situ maximum and minimum temperatures of present-day, and geographic auxiliary variables. There are two outputs (i.e. next-day maximum and minimum air temperatures) in this data. Hindcast validation was conducted for the period from 2015 to 2017.
#
# ### Attribute Information:
#
# Attribute Information:
#
# 1. station - used weather station number: 1 to 25
# 2. Date - Present day: yyyy-mm-dd ('2013-06-30' to '2017-08-30')
# 3. Present_Tmax - Maximum air temperature between 0 and 21 h on the present day (Â°C): 20 to 37.6
# 4. Present_Tmin - Minimum air temperature between 0 and 21 h on the present day (Â°C): 11.3 to 29.9
# 5. LDAPS_RHmin - LDAPS model forecast of next-day minimum relative humidity (%): 19.8 to 98.5
# 6. LDAPS_RHmax - LDAPS model forecast of next-day maximum relative humidity (%): 58.9 to 100
# 7. LDAPS_Tmax_lapse - LDAPS model forecast of next-day maximum air temperature applied lapse rate (Â°C): 17.6 to 38.5
# 8. LDAPS_Tmin_lapse - LDAPS model forecast of next-day minimum air temperature applied lapse rate (Â°C): 14.3 to 29.6
# 9. LDAPS_WS - LDAPS model forecast of next-day average wind speed (m/s): 2.9 to 21.9
# 10. LDAPS_LH - LDAPS model forecast of next-day average latent heat flux (W/m2): -13.6 to 213.4
# 11. LDAPS_CC1 - LDAPS model forecast of next-day 1st 6-hour split average cloud cover (0-5 h) (%): 0 to 0.97
# 12. LDAPS_CC2 - LDAPS model forecast of next-day 2nd 6-hour split average cloud cover (6-11 h) (%): 0 to 0.97
# 13. LDAPS_CC3 - LDAPS model forecast of next-day 3rd 6-hour split average cloud cover (12-17 h) (%): 0 to 0.98
# 14. LDAPS_CC4 - LDAPS model forecast of next-day 4th 6-hour split average cloud cover (18-23 h) (%): 0 to 0.97
# 15. LDAPS_PPT1 - LDAPS model forecast of next-day 1st 6-hour split average precipitation (0-5 h) (%): 0 to 23.7
# 16. LDAPS_PPT2 - LDAPS model forecast of next-day 2nd 6-hour split average precipitation (6-11 h) (%): 0 to 21.6
# 17. LDAPS_PPT3 - LDAPS model forecast of next-day 3rd 6-hour split average precipitation (12-17 h) (%): 0 to 15.8
# 18. LDAPS_PPT4 - LDAPS model forecast of next-day 4th 6-hour split average precipitation (18-23 h) (%): 0 to 16.7
# 19. lat - Latitude (Â°): 37.456 to 37.645
# 20. lon - Longitude (Â°): 126.826 to 127.135
# 21. DEM - Elevation (m): 12.4 to 212.3
# 22. Slope - Slope (Â°): 0.1 to 5.2
# 23. Solar radiation - Daily incoming solar radiation (wh/m2): 4329.5 to 5992.9
# 24. Next_Tmax - The next-day maximum air temperature (Â°C): 17.4 to 38.9
# 25. Next_Tmin - The next-day minimum air temperature (Â°C): 11.3 to 29.8T

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Temperature Forecast.csv')
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# 1       90.604721         29.850689         24.035009   5.691890   51.937448
# 2       83.973587         30.091292         24.565633   6.138224   20.573050
# 3       96.483688         29.704629         23.326177   5.650050   65.727144
# 4       90.155128         29.113934         23.486480   5.735004  107.965535
# ...           ...               ...               ...        ...         ...
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0     ...    0.000000    0.000000    0.000000  37.6046  126.991  212.3350
# 1     ...    0.000000    0.000000    0.000000  37.6046  127.032   44.7624
# 2     ...    0.000000    0.000000    0.000000  37.5776  127.058   33.3068
# 3     ...    0.000000    0.000000    0.000000  37.6450  127.022   45.7160
# 4     ...    0.000000    0.000000    0.000000  37.5507  127.135   35.0380
# ...   ...         ...         ...         ...      ...      ...       ...
# 7747  ...    0.000000    0.000000    0.000000  37.5372  126.891   15.5876
# 7748  ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 7749  ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 7750  ...    0.000000    0.000000    0.000000  37.4562  126.826   12.3700
# 7751  ...   21.621661   15.841235   16.655469  37.6450  127.135  212.3350
#
#          Slope  Solar radiation  Next_Tmax  Next_Tmin
# 0     2.785000      5992.895996       29.1       21.2
# 1     0.514100      5869.312500       30.5       22.5
# 2     0.266100      5863.555664       31.1       23.9
# 3     2.534800      5856.964844       31.7       24.3
# 4     0.505500      5859.552246       31.2       22.5
# ...        ...              ...        ...        ...
# 7747  0.155400      4443.313965       28.3       18.1
# 7748  0.222300      4438.373535       28.6       18.8
# 7749  0.271300      4451.345215       27.8       17.4
# 7750  0.098475      4329.520508       17.4       11.3
# 7751  5.178230      5992.895996       38.9       29.8
#
# [7752 rows x 25 columns]

# %%
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0         0.0         0.0  37.6046  126.991  212.3350  2.7850
# 1         0.0         0.0  37.6046  127.032   44.7624  0.5141
# 2         0.0         0.0  37.5776  127.058   33.3068  0.2661
# 3         0.0         0.0  37.6450  127.022   45.7160  2.5348
# 4         0.0         0.0  37.5507  127.135   35.0380  0.5055
#
#    Solar radiation  Next_Tmax  Next_Tmin
# 0      5992.895996       29.1       21.2
# 1      5869.312500       30.5       22.5
# 2      5863.555664       31.1       23.9
# 3      5856.964844       31.7       24.3
# 4      5859.552246       31.2       22.5
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (7752, 25)

# %% [markdown]
# This dataset has 7752 rows and 25 columns.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %% [markdown]
# We have float type in almost all columns except for the date column we have object type. The both target variables Next_Tmax and Next_Tmin are in float type.

# %% [markdown]
# ### Checking for null values

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
#filling the missing values for numerical terms by mean
df['station']=df['station'].fillna(df['station'].mean())
df['Present_Tmax']=df['Present_Tmax'].fillna(df['Present_Tmax'].mean())
df['Present_Tmin']=df['Present_Tmin'].fillna(df['Present_Tmin'].mean())
df['LDAPS_RHmin']=df['LDAPS_RHmin'].fillna(df['LDAPS_RHmin'].mean())
df['LDAPS_RHmax']=df['LDAPS_RHmax'].fillna(df['LDAPS_RHmax'].mean())
df['LDAPS_Tmax_lapse']=df['LDAPS_Tmax_lapse'].fillna(df['LDAPS_Tmax_lapse'].mean())
df['LDAPS_Tmin_lapse']=df['LDAPS_Tmin_lapse'].fillna(df['LDAPS_Tmin_lapse'].mean())
df['LDAPS_WS']=df['LDAPS_WS'].fillna(df['LDAPS_WS'].mean())
df['LDAPS_LH']=df['LDAPS_LH'].fillna(df['LDAPS_LH'].mean())
df['LDAPS_CC1']=df['LDAPS_CC1'].fillna(df['LDAPS_CC1'].mean())
df['LDAPS_CC2']=df['LDAPS_CC2'].fillna(df['LDAPS_CC2'].mean())
df['LDAPS_CC3']=df['LDAPS_CC3'].fillna(df['LDAPS_CC3'].mean())
df['LDAPS_CC4']=df['LDAPS_CC4'].fillna(df['LDAPS_CC4'].mean())
df['LDAPS_PPT1']=df['LDAPS_PPT1'].fillna(df['LDAPS_PPT1'].mean())
df['LDAPS_PPT2']=df['LDAPS_PPT2'].fillna(df['LDAPS_PPT2'].mean())
df['LDAPS_PPT3']=df['LDAPS_PPT3'].fillna(df['LDAPS_PPT3'].mean())
df['LDAPS_PPT4']=df['LDAPS_PPT4'].fillna(df['LDAPS_PPT4'].mean())
df['Next_Tmax']=df['Next_Tmax'].fillna(df['Next_Tmax'].mean())
df['Next_Tmin']=df['Next_Tmin'].fillna(df['Next_Tmin'].mean())

# %% [markdown]
# Fill null values with it's mwean for the columns which have null values.

# %%
df.isnull().sum()
# Out:
# station             0
# Date                2
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %% [markdown]
# We still have missing values in date column.

# %%
import datetime as ddt
df['Date']=pd.to_datetime(df['Date'])
df['Date']=df['Date'].map(ddt.datetime.toordinal)

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %% [markdown]
# Now there are no null values in this dataset.

# %%
df.head()
# Out:
#    station    Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  735049          28.7          21.4    58.255688    91.116364
# 1      2.0  735049          31.9          21.6    52.263397    90.604721
# 2      3.0  735049          31.6          23.3    48.690479    83.973587
# 3      4.0  735049          32.0          23.4    58.239788    96.483688
# 4      5.0  735049          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0         0.0         0.0  37.6046  126.991  212.3350  2.7850
# 1         0.0         0.0  37.6046  127.032   44.7624  0.5141
# 2         0.0         0.0  37.5776  127.058   33.3068  0.2661
# 3         0.0         0.0  37.6450  127.022   45.7160  2.5348
# 4         0.0         0.0  37.5507  127.135   35.0380  0.5055
#
#    Solar radiation  Next_Tmax  Next_Tmin
# 0      5992.895996       29.1       21.2
# 1      5869.312500       30.5       22.5
# 2      5863.555664       31.1       23.9
# 3      5856.964844       31.7       24.3
# 4      5859.552246       31.2       22.5
#
# [5 rows x 25 columns]

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=l.fit_transform(df[i].values)

# %% [markdown]
# Converting all Object attributes into Numerical attributes by using LabelEncoder.

# %%
df.head()
# Out:
#    station    Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  735049          28.7          21.4    58.255688    91.116364
# 1      2.0  735049          31.9          21.6    52.263397    90.604721
# 2      3.0  735049          31.6          23.3    48.690479    83.973587
# 3      4.0  735049          32.0          23.4    58.239788    96.483688
# 4      5.0  735049          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0         0.0         0.0  37.6046  126.991  212.3350  2.7850
# 1         0.0         0.0  37.6046  127.032   44.7624  0.5141
# 2         0.0         0.0  37.5776  127.058   33.3068  0.2661
# 3         0.0         0.0  37.6450  127.022   45.7160  2.5348
# 4         0.0         0.0  37.5507  127.135   35.0380  0.5055
#
#    Solar radiation  Next_Tmax  Next_Tmin
# 0      5992.895996       29.1       21.2
# 1      5869.312500       30.5       22.5
# 2      5863.555664       31.1       23.9
# 3      5856.964844       31.7       24.3
# 4      5859.552246       31.2       22.5
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7752 non-null   float64
#  1   Date              7752 non-null   int64
#  2   Present_Tmax      7752 non-null   float64
#  3   Present_Tmin      7752 non-null   float64
#  4   LDAPS_RHmin       7752 non-null   float64
#  5   LDAPS_RHmax       7752 non-null   float64
#  6   LDAPS_Tmax_lapse  7752 non-null   float64
#  7   LDAPS_Tmin_lapse  7752 non-null   float64
#  8   LDAPS_WS          7752 non-null   float64
#  9   LDAPS_LH          7752 non-null   float64
#  10  LDAPS_CC1         7752 non-null   float64
#  11  LDAPS_CC2         7752 non-null   float64
#  12  LDAPS_CC3         7752 non-null   float64
#  13  LDAPS_CC4         7752 non-null   float64
#  14  LDAPS_PPT1        7752 non-null   float64
#  15  LDAPS_PPT2        7752 non-null   float64
#  16  LDAPS_PPT3        7752 non-null   float64
#  17  LDAPS_PPT4        7752 non-null   float64
#  18  lat               7752 non-null   float64
#  19  lon               7752 non-null   float64
#  20  DEM               7752 non-null   float64
#  21  Slope             7752 non-null   float64
#  22  Solar radiation   7752 non-null   float64
#  23  Next_Tmax         7752 non-null   float64
#  24  Next_Tmin         7752 non-null   float64
# dtypes: float64(24), int64(1)
# memory usage: 1.5 MB

# %% [markdown]
# As we can see that 'date' is now converted into integer data type.

# %%
plt.hist(df['Next_Tmax'])
plt.xlabel('Next_Tmax')
plt.title('Maximum Temperature Prediction')
# Out:
# Text(0.5, 1.0, 'Maximum Temperature Prediction')

# %% [markdown]
# Distribution of data across Maximum Temperature Prediction.

# %%
import seaborn as sns
plt.title('Next day maximum Temperature')
sns.distplot(df['Next_Tmax'],kde=True)

# %% [markdown]
# The distplot shows that next day maximum temparature distribution is lies between 22 to 37

# %%
plt.hist(df['Next_Tmin'])
plt.xlabel('Next_Tmin')
plt.title('Minimum Temperature Prediction')
# Out:
# Text(0.5, 1.0, 'Minimum Temperature Prediction')

# %% [markdown]
# Graph shows the distribution of data across Minimum Temperature Prediction.

# %%
plt.title('Next day minimum Temperature')
sns.distplot(df['Next_Tmin'],kde=True)

# %% [markdown]
# The distplot shows that next day minimum temparature distribution is lies between 15 to 28.

# %%
plt.figure(figsize=(30,5))
plt.title('Present maximum Temperature VS Next day maximum Temperature')
plt.scatter(df['Present_Tmax'], df['Next_Tmax'])
plt.xlabel('Present_Tmax')
plt.ylabel('Next_Tmax')
# Out:
# Text(0, 0.5, 'Next_Tmax')

# %% [markdown]
# Scatterplot graph shows the distribution of data across Present maximum Temperature VS Next day maximum Temperature.

# %%
plt.figure(figsize=(30,5))
plt.title('Present minimum Temperature VS Next day minimum Temperature')
plt.scatter(df['Present_Tmin'], df['Next_Tmin'])
plt.xlabel('Present_Tmin')
plt.ylabel('Next_Tmin')
# Out:
# Text(0, 0.5, 'Next_Tmin')

# %% [markdown]
# Scatterplot graph shows that distribution of data across Present minimum Temperature VS Next day minimum Temperature.

# %%
plt.figure(figsize=(30,5))
plt.title('LDAPS model forecast of next-day minimum air temperature applied lapse rate VS Next day minimum Temperature')
plt.scatter(df['LDAPS_Tmin_lapse'], df['Next_Tmin'])
plt.xlabel('LDAPS_Tmin_lapse')
plt.ylabel('Next_Tmin')
# Out:
# Text(0, 0.5, 'Next_Tmin')

# %% [markdown]
# Scatterplot shows distribution of data across LDAPS model forecast of next-day minimum air temperature applied lapse rate VS Next day minimum Temperature.

# %%
plt.figure(figsize=(20,5))
plt.title('Daily incoming solar radiation vs Next day minimum Temperature')
sns.lineplot(x='Solar radiation',y='Next_Tmin',data=df)
plt.show()

# %% [markdown]
# Lineplot shows distribution of data across Daily incoming solar radiation vs Next day minimum Temperature.
#
# As per solar radiation, the next day minimum temparature is frequently increases.

# %%
plt.figure(figsize=(20,5))
plt.title('Daily incoming solar radiation vs Next day maximum Temperature')
sns.lineplot(x='Solar radiation',y='Next_Tmax',data=df)
plt.show()

# %% [markdown]
# As per solar radiation, the next day maximum temparature is frequently increases.
#
# Lineplot shows distribution of data across Daily incoming solar radiation vs Next day maximum Temperature.

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.describe(),annot=True,linewidths=1,linecolor='black',cmap='Reds',fmt='0.2f')

# %% [markdown]
# ### Correlation Matrix

# %%
df_corr=df.corr()
df_corr
# Out:
#                    station      Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000  0.000000      0.112655      0.131646    -0.066733
# Date              0.000000  1.000000      0.007766      0.019074    -0.003083
# Present_Tmax      0.112655  0.007766      1.000000      0.618760    -0.204571
# Present_Tmin      0.131646  0.019074      0.618760      1.000000     0.123143
# LDAPS_RHmin      -0.066733 -0.003083     -0.204571      0.123143     1.000000
# LDAPS_RHmax      -0.166984  0.013541     -0.301787     -0.015140     0.579141
# LDAPS_Tmax_lapse  0.069107  0.008840      0.570129      0.464151    -0.564580
# LDAPS_Tmin_lapse  0.104758  0.010287      0.623496      0.762993     0.089476
# LDAPS_WS          0.005277 -0.044282     -0.121820     -0.034675     0.294361
# LDAPS_LH         -0.133357 -0.015528      0.135463     -0.009258    -0.070858
# LDAPS_CC1         0.006919 -0.010413     -0.311805      0.084447     0.613818
# LDAPS_CC2         0.003396 -0.010414     -0.213791      0.090263     0.745443
# LDAPS_CC3         0.000694 -0.006590     -0.144018     -0.002772     0.689679
# LDAPS_CC4         0.006126 -0.007504     -0.140729     -0.044335     0.514075
# LDAPS_PPT1       -0.002709 -0.097386     -0.109006      0.112845     0.262665
# LDAPS_PPT2       -0.008250 -0.096594     -0.099449      0.068176     0.390967
# LDAPS_PPT3       -0.012461 -0.103827     -0.120367     -0.046126     0.240642
# LDAPS_PPT4       -0.010401 -0.106507     -0.099607     -0.062965     0.168595
# lat              -0.237502 -0.001874     -0.052615     -0.078475     0.087099
# lon              -0.118704  0.002202      0.009020     -0.043461    -0.076237
# DEM              -0.255830 -0.014928     -0.187121     -0.250275     0.102115
# Slope            -0.090061 -0.016177     -0.105809     -0.146339     0.123744
# Solar radiation  -0.019001  0.004326     -0.025439      0.053578     0.244080
# Next_Tmax         0.107983  0.013306      0.610348      0.471806    -0.437898
# Next_Tmin         0.128293  0.016178      0.622741      0.796670     0.095019
#
#                   LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  \
# station             -0.166984          0.069107          0.104758  0.005277
# Date                 0.013541          0.008840          0.010287 -0.044282
# Present_Tmax        -0.301787          0.570129          0.623496 -0.121820
# Present_Tmin        -0.015140          0.464151          0.762993 -0.034675
# LDAPS_RHmin          0.579141         -0.564580          0.089476  0.294361
# LDAPS_RHmax          1.000000         -0.373404         -0.114143  0.135333
# LDAPS_Tmax_lapse    -0.373404          1.000000          0.654021 -0.311996
# LDAPS_Tmin_lapse    -0.114143          0.654021          1.000000 -0.130035
# LDAPS_WS             0.135333         -0.311996         -0.130035  1.000000
# LDAPS_LH             0.238579          0.048010         -0.134761  0.006711
# LDAPS_CC1            0.436652         -0.438439          0.010901  0.289445
# LDAPS_CC2            0.391330         -0.523619          0.047727  0.261090
# LDAPS_CC3            0.226957         -0.541327         -0.044018  0.242991
# LDAPS_CC4            0.130619         -0.429539         -0.080335  0.220533
# LDAPS_PPT1           0.268449         -0.111065          0.038056  0.152587
# LDAPS_PPT2           0.229050         -0.242122          0.000870  0.191886
# LDAPS_PPT3           0.134607         -0.188115         -0.088575  0.161684
# LDAPS_PPT4           0.117853         -0.160273         -0.094655  0.144085
# lat                  0.195798         -0.042093         -0.096257  0.036657
# lon                  0.025667          0.090666         -0.026701 -0.059466
# DEM                  0.177168         -0.178895         -0.195455  0.191053
# Slope                0.219599         -0.162332         -0.185849  0.171629
# Solar radiation      0.149261          0.047971          0.159975  0.121759
# Next_Tmax           -0.283738          0.827189          0.586983 -0.342729
# Next_Tmin           -0.071997          0.586868          0.880176 -0.096576
#
#                   LDAPS_LH  ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4       lat  \
# station          -0.133357  ...   -0.008250   -0.012461   -0.010401 -0.237502
# Date             -0.015528  ...   -0.096594   -0.103827   -0.106507 -0.001874
# Present_Tmax      0.135463  ...   -0.099449   -0.120367   -0.099607 -0.052615
# Present_Tmin     -0.009258  ...    0.068176   -0.046126   -0.062965 -0.078475
# LDAPS_RHmin      -0.070858  ...    0.390967    0.240642    0.168595  0.087099
# LDAPS_RHmax       0.238579  ...    0.229050    0.134607    0.117853  0.195798
# LDAPS_Tmax_lapse  0.048010  ...   -0.242122   -0.188115   -0.160273 -0.042093
# LDAPS_Tmin_lapse -0.134761  ...    0.000870   -0.088575   -0.094655 -0.096257
# LDAPS_WS          0.006711  ...    0.191886    0.161684    0.144085  0.036657
# LDAPS_LH          1.000000  ...   -0.077545    0.016102    0.019979  0.133221
# LDAPS_CC1        -0.147296  ...    0.389453    0.168742    0.091722 -0.008131
# LDAPS_CC2        -0.264280  ...    0.478472    0.240134    0.159548 -0.001497
# LDAPS_CC3        -0.245583  ...    0.337569    0.339800    0.302357  0.004108
# LDAPS_CC4        -0.172766  ...    0.288195    0.267494    0.376049 -0.009107
# LDAPS_PPT1       -0.012542  ...    0.383831    0.033004    0.024626  0.000565
# LDAPS_PPT2       -0.077545  ...    1.000000    0.221172    0.139555  0.019564
# LDAPS_PPT3        0.016102  ...    0.221172    1.000000    0.309076  0.035110
# LDAPS_PPT4        0.019979  ...    0.139555    0.309076    1.000000  0.013210
# lat               0.133221  ...    0.019564    0.035110    0.013210  1.000000
# lon               0.025822  ...    0.018600    0.021662    0.044746  0.289029
# DEM               0.055133  ...    0.008357    0.017186   -0.003622  0.033165
# Slope             0.086781  ...    0.010214    0.025333    0.000117  0.074763
# Solar radiation  -0.047384  ...    0.110182   -0.054071    0.034958  0.038513
# Next_Tmax         0.157616  ...   -0.178383   -0.194143   -0.178718 -0.053510
# Next_Tmin        -0.055440  ...   -0.008058   -0.062622   -0.103682 -0.083533
#
#                        lon       DEM     Slope  Solar radiation  Next_Tmax  \
# station          -0.118704 -0.255830 -0.090061        -0.019001   0.107983
# Date              0.002202 -0.014928 -0.016177         0.004326   0.013306
# Present_Tmax      0.009020 -0.187121 -0.105809        -0.025439   0.610348
# Present_Tmin     -0.043461 -0.250275 -0.146339         0.053578   0.471806
# LDAPS_RHmin      -0.076237  0.102115  0.123744         0.244080  -0.437898
# LDAPS_RHmax       0.025667  0.177168  0.219599         0.149261  -0.283738
# LDAPS_Tmax_lapse  0.090666 -0.178895 -0.162332         0.047971   0.827189
# LDAPS_Tmin_lapse -0.026701 -0.195455 -0.185849         0.159975   0.586983
# LDAPS_WS         -0.059466  0.191053  0.171629         0.121759  -0.342729
# LDAPS_LH          0.025822  0.055133  0.086781        -0.047384   0.157616
# LDAPS_CC1        -0.006843 -0.014090 -0.020752         0.218309  -0.452541
# LDAPS_CC2        -0.003581 -0.012823 -0.018073         0.170403  -0.490756
# LDAPS_CC3         0.016041  0.000697 -0.003338         0.119292  -0.514680
# LDAPS_CC4        -0.002477 -0.007334 -0.014459         0.119983  -0.446319
# LDAPS_PPT1       -0.001225  0.011290  0.016310         0.088015  -0.118817
# LDAPS_PPT2        0.018600  0.008357  0.010214         0.110182  -0.178383
# LDAPS_PPT3        0.021662  0.017186  0.025333        -0.054071  -0.194143
# LDAPS_PPT4        0.044746 -0.003622  0.000117         0.034958  -0.178718
# lat               0.289029  0.033165  0.074763         0.038513  -0.053510
# lon               1.000000  0.007587  0.038070         0.002182   0.003052
# DEM               0.007587  1.000000  0.783576         0.056224  -0.172538
# Slope             0.038070  0.783576  1.000000         0.028199  -0.102725
# Solar radiation   0.002182  0.056224  0.028199         1.000000   0.008795
# Next_Tmax         0.003052 -0.172538 -0.102725         0.008795   1.000000
# Next_Tmin        -0.046603 -0.246906 -0.146882         0.120212   0.621427
#
#                   Next_Tmin
# station            0.128293
# Date               0.016178
# Present_Tmax       0.622741
# Present_Tmin       0.796670
# LDAPS_RHmin        0.095019
# LDAPS_RHmax       -0.071997
# LDAPS_Tmax_lapse   0.586868
# LDAPS_Tmin_lapse   0.880176
# LDAPS_WS          -0.096576
# LDAPS_LH          -0.055440
# LDAPS_CC1         -0.011028
# LDAPS_CC2          0.031250
# LDAPS_CC3         -0.054726
# LDAPS_CC4         -0.085093
# LDAPS_PPT1         0.021323
# LDAPS_PPT2        -0.008058
# LDAPS_PPT3        -0.062622
# LDAPS_PPT4        -0.103682
# lat               -0.083533
# lon               -0.046603
# DEM               -0.246906
# Slope             -0.146882
# Solar radiation    0.120212
# Next_Tmax          0.621427
# Next_Tmin          1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# Checked correlation in dataset.

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_corr,annot=True,linewidths=1,linecolor='black',cmap="Blues",fmt='0.2f')

# %% [markdown]
# Heatmap shows distribution of data across all level of category.

# %% [markdown]
# ### Removing Outliers using zscore.

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.66431530e+00, 4.73283412e-02, 3.61325771e-01, ...,
#         1.51793488e+00, 3.76282142e-01, 6.97599301e-01],
#        [1.52562236e+00, 4.73283412e-02, 7.21084007e-01, ...,
#         1.22994952e+00, 7.20972505e-02, 1.74063574e-01],
#        [1.38692941e+00, 4.73283412e-02, 6.19608090e-01, ...,
#         1.21653443e+00, 2.64259847e-01, 3.89744132e-01],
#        ...,
#        [1.66431530e+00, 8.13430765e-02, 2.22171758e+00, ...,
#         2.07432510e+00, 7.92634435e-01, 2.22793450e+00],
#        [0.00000000e+00, 6.21890289e+01, 3.30412736e+00, ...,
#         2.35821196e+00, 4.12345278e+00, 4.68452522e+00],
#        [0.00000000e+00, 6.21890289e+01, 2.64912642e+00, ...,
#         1.51793488e+00, 2.76237361e+00, 2.76579089e+00]])

# %%
df_new=df[(z<3).all(axis=1)]
df_new.head()
# Out:
#    station    Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  735049          28.7          21.4    58.255688    91.116364
# 1      2.0  735049          31.9          21.6    52.263397    90.604721
# 2      3.0  735049          31.6          23.3    48.690479    83.973587
# 3      4.0  735049          32.0          23.4    58.239788    96.483688
# 4      5.0  735049          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0         0.0         0.0  37.6046  126.991  212.3350  2.7850
# 1         0.0         0.0  37.6046  127.032   44.7624  0.5141
# 2         0.0         0.0  37.5776  127.058   33.3068  0.2661
# 3         0.0         0.0  37.6450  127.022   45.7160  2.5348
# 4         0.0         0.0  37.5507  127.135   35.0380  0.5055
#
#    Solar radiation  Next_Tmax  Next_Tmin
# 0      5992.895996       29.1       21.2
# 1      5869.312500       30.5       22.5
# 2      5863.555664       31.1       23.9
# 3      5856.964844       31.7       24.3
# 4      5859.552246       31.2       22.5
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (7752, 25)

# %%
df_new.shape
# Out:
# (6894, 25)

# %% [markdown]
# Here we can see that the outliers have been removed from the dataset.

# %%
Data_loss=((7752-6894)/7752*100)
Data_loss
# Out:
# 11.06811145510836

# %% [markdown]
# We lost 11% of data and that is in the acceptable range.

# %% [markdown]
# ### Separting into Target and Feature

# %%
x= df_new.drop('Next_Tmax',axis=1)
y= df_new['Next_Tmax']

# %% [markdown]
# ### Checking Skewness

# %%
df_new.skew()
# Out:
# station             0.002792
# Date                0.009490
# Present_Tmax       -0.272653
# Present_Tmin       -0.225479
# LDAPS_RHmin         0.305740
# LDAPS_RHmax        -0.688257
# LDAPS_Tmax_lapse   -0.109372
# LDAPS_Tmin_lapse   -0.382667
# LDAPS_WS            1.087781
# LDAPS_LH            0.568781
# LDAPS_CC1           0.593990
# LDAPS_CC2           0.500911
# LDAPS_CC3           0.700217
# LDAPS_CC4           0.710930
# LDAPS_PPT1          3.731226
# LDAPS_PPT2          4.843672
# LDAPS_PPT3          5.482625
# LDAPS_PPT4          5.927822
# lat                 0.108251
# lon                -0.275508
# DEM                 1.764031
# Slope               1.593600
# Solar radiation    -0.505353
# Next_Tmax          -0.270084
# Next_Tmin          -0.237767
# dtype: float64

# %% [markdown]
# ### Using power transform to reduce skewness

# %%
from sklearn.preprocessing import power_transform
df_max=power_transform(x)

df_max=pd.DataFrame(df_max,columns=x.columns)

# %%
df_max.skew()
# Out:
# station            -0.201793
# Date                0.007630
# Present_Tmax       -0.031861
# Present_Tmin       -0.021731
# LDAPS_RHmin        -0.013773
# LDAPS_RHmax        -0.098610
# LDAPS_Tmax_lapse   -0.011202
# LDAPS_Tmin_lapse   -0.025139
# LDAPS_WS            0.006111
# LDAPS_LH           -0.029488
# LDAPS_CC1           0.062650
# LDAPS_CC2           0.047088
# LDAPS_CC3           0.090316
# LDAPS_CC4           0.137619
# LDAPS_PPT1          1.546602
# LDAPS_PPT2          1.736072
# LDAPS_PPT3          1.903031
# LDAPS_PPT4          2.157042
# lat                 0.000000
# lon                -0.189409
# DEM                 0.038729
# Slope               0.233805
# Solar radiation    -0.166145
# Next_Tmin          -0.021823
# dtype: float64

# %%
m= df_new.drop('Next_Tmin',axis=1)
n= df_new['Next_Tmin']

# %%
from sklearn.preprocessing import power_transform
df_min=power_transform(m)

df_min=pd.DataFrame(df_min,columns=m.columns)

# %%
df_min.skew()
# Out:
# station            -0.201793
# Date                0.007630
# Present_Tmax       -0.031861
# Present_Tmin       -0.021731
# LDAPS_RHmin        -0.013773
# LDAPS_RHmax        -0.098610
# LDAPS_Tmax_lapse   -0.011202
# LDAPS_Tmin_lapse   -0.025139
# LDAPS_WS            0.006111
# LDAPS_LH           -0.029488
# LDAPS_CC1           0.062650
# LDAPS_CC2           0.047088
# LDAPS_CC3           0.090316
# LDAPS_CC4           0.137619
# LDAPS_PPT1          1.546602
# LDAPS_PPT2          1.736072
# LDAPS_PPT3          1.903031
# LDAPS_PPT4          2.157042
# lat                 0.000000
# lon                -0.189409
# DEM                 0.038729
# Slope               0.233805
# Solar radiation    -0.166145
# Next_Tmax          -0.035691
# dtype: float64

# %%
m=df_max
m.head()
# Out:
#     station      Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0 -1.871049 -1.445578     -0.480198     -0.847876     0.255239     0.347753
# 1 -1.658471 -1.445578      0.668526     -0.765965    -0.177754     0.259931
# 2 -1.464383 -1.445578      0.555342     -0.045094    -0.448722    -0.726467
# 3 -1.282978 -1.445578      0.706507     -0.001324     0.254123     1.383197
# 4 -1.111079 -1.445578      0.480519     -0.641952     0.107664     0.184230
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  ...  LDAPS_PPT1  \
# 0         -0.673802         -0.357939  0.170447  0.348275  ...   -0.538255
# 1         -0.030722          0.111292 -0.584135 -0.171949  ...   -0.538255
# 2          0.057585          0.364952 -0.260420 -1.388942  ...   -0.538255
# 3         -0.084189         -0.215346 -0.616421  0.243476  ...   -0.538255
# 4         -0.299338         -0.142691 -0.551233  1.303975  ...   -0.538255
#
#    LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4           lat       lon       DEM  \
# 0   -0.498268   -0.475132   -0.428118  5.689893e-14 -0.020409  1.854276
# 1   -0.498268   -0.475132   -0.428118  5.689893e-14  0.502989  0.069427
# 2   -0.498268   -0.475132   -0.428118  3.175238e-14  0.841275 -0.353718
# 3   -0.498268   -0.475132   -0.428118  9.423018e-14  0.374205  0.098490
# 4   -0.498268   -0.475132   -0.428118  6.605827e-15  1.872937 -0.279099
#
#       Slope  Solar radiation  Next_Tmin
# 0  1.329510         1.889266  -0.823152
# 1 -0.374447         1.434120  -0.290265
# 2 -0.943391         1.413770   0.312510
# 3  1.250934         1.390562   0.490201
# 4 -0.390970         1.399661  -0.290265
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Creating Models to find out the best model

# %%
#models froms sickit learn
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso,Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

#ensemble technique
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

# Importing some metrics we can use to evaluate our model performance.... 
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
LR=LinearRegression()
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    LR.fit(x_train,y_train)
    pred_train=LR.predict(x_train)
    pred_test=LR.predict(x_test)
    print('At random state',i,'Training accuracy is:', r2_score(y_train,pred_train))
    print('At random state',i,'Testing accuracy is:',r2_score(y_test,pred_test))
    print('\n')
# Out:
# At random state 0 Training accuracy is: 0.7771997222163329
# At random state 0 Testing accuracy is: 0.7660816642546205
#
#
# At random state 1 Training accuracy is: 0.771538204584393
# At random state 1 Testing accuracy is: 0.77881657215777
#
#
# At random state 2 Training accuracy is: 0.7787777416990662
# At random state 2 Testing accuracy is: 0.761894710429601
#
#
# At random state 3 Training accuracy is: 0.7742737845416607
# At random state 3 Testing accuracy is: 0.7729660773344678
#
#
# At random state 4 Training accuracy is: 0.7807081064221261
# At random state 4 Testing accuracy is: 0.7566593174305802
#
#
# At random state 5 Training accuracy is: 0.7721718532923793
# At random state 5 Testing accuracy is: 0.7779070902794328
#
#
# At random state 6 Training accuracy is: 0.7707099926772563
# At random state 6 Testing accuracy is: 0.7814717510641821
#
#
# At random state 7 Training accuracy is: 0.7755302817983052
# At random state 7 Testing accuracy is: 0.7701003057237598
#
#
# At random state 8 Training accuracy is: 0.7802160264616099
# At random state 8 Testing accuracy is: 0.7594057878834478
#
#
# At random state 9 Training accuracy is: 0.7729141325207026
# At random state 9 Testing accuracy is: 0.7760553309915227
#
#
# At random state 10 Training accuracy is: 0.7805192665592613
# At random state 10 Testing accuracy is: 0.7576468800652273
#
#
# At random state 11 Training accuracy is: 0.7701999681145116
# At random state 11 Testing accuracy is: 0.7816926234352554
#
#
# At random state 12 Training accuracy is: 0.7735259409897947
# At random state 12 Testing accuracy is: 0.7743266396222779
#
#
# At random state 13 Training accuracy is: 0.7720671376705237
# At random state 13 Testing accuracy is: 0.778096178997435
#
#
# At random state 14 Training accuracy is: 0.7765955688018699
# At random state 14 Testing accuracy is: 0.767711339484637
#
#
# At random state 15 Training accuracy is: 0.7757886600930111
# At random state 15 Testing accuracy is: 0.7700768913008487
#
#
# At random state 16 Training accuracy is: 0.7719452493880969
# At random state 16 Testing accuracy is: 0.7785872261562851
#
#
# At random state 17 Training accuracy is: 0.7759375723144852
# At random state 17 Testing accuracy is: 0.7690595816046322
#
#
# At random state 18 Training accuracy is: 0.7724474880312459
# At random state 18 Testing accuracy is: 0.7770822565089364
#
#
# At random state 19 Training accuracy is: 0.7732050977795457
# At random state 19 Testing accuracy is: 0.7761560726182668
#
#
# At random state 20 Training accuracy is: 0.7833564824807228
# At random state 20 Testing accuracy is: 0.7501381240130698
#
#
# At random state 21 Training accuracy is: 0.7782276342926593
# At random state 21 Testing accuracy is: 0.7622824596318705
#
#
# At random state 22 Training accuracy is: 0.7714700358652635
# At random state 22 Testing accuracy is: 0.7788677329138842
#
#
# At random state 23 Training accuracy is: 0.783363153884442
# At random state 23 Testing accuracy is: 0.7516559297317984
#
#
# At random state 24 Training accuracy is: 0.7721804514439372
# At random state 24 Testing accuracy is: 0.7777293435071024
#
#
# At random state 25 Training accuracy is: 0.7755272583579566
# At random state 25 Testing accuracy is: 0.7700170778728075
#
#
# At random state 26 Training accuracy is: 0.7742514229742038
# At random state 26 Testing accuracy is: 0.7723673001616415
#
#
# At random state 27 Training accuracy is: 0.780222761478558
# At random state 27 Testing accuracy is: 0.7588621184648887
#
#
# At random state 28 Training accuracy is: 0.776869102169197
# At random state 28 Testing accuracy is: 0.7668878221998624
#
#
# At random state 29 Training accuracy is: 0.7736740751496696
# At random state 29 Testing accuracy is: 0.7737735036291777
#
#
# At random state 30 Training accuracy is: 0.7711115212071074
# At random state 30 Testing accuracy is: 0.7803150286925018
#
#
# At random state 31 Training accuracy is: 0.7730727997497917
# At random state 31 Testing accuracy is: 0.7749712331300097
#
#
# At random state 32 Training accuracy is: 0.7793054971405752
# At random state 32 Testing accuracy is: 0.7616376944931037
#
#
# At random state 33 Training accuracy is: 0.7690521789711124
# At random state 33 Testing accuracy is: 0.7852831425207061
#
#
# At random state 34 Training accuracy is: 0.7744620760465573
# At random state 34 Testing accuracy is: 0.7719481336561193
#
#
# At random state 35 Training accuracy is: 0.7735198841298287
# At random state 35 Testing accuracy is: 0.7754924570777818
#
#
# At random state 36 Training accuracy is: 0.773572531429332
# At random state 36 Testing accuracy is: 0.7741323513236449
#
#
# At random state 37 Training accuracy is: 0.7802083608491188
# At random state 37 Testing accuracy is: 0.7582677946522405
#
#
# At random state 38 Training accuracy is: 0.7768945421686376
# At random state 38 Testing accuracy is: 0.7658116800132453
#
#
# At random state 39 Training accuracy is: 0.7751446160020548
# At random state 39 Testing accuracy is: 0.7709088930771276
#
#
# At random state 40 Training accuracy is: 0.7740970369090227
# At random state 40 Testing accuracy is: 0.7737209158963475
#
#
# At random state 41 Training accuracy is: 0.7766770605631741
# At random state 41 Testing accuracy is: 0.7680499645471087
#
#
# At random state 42 Training accuracy is: 0.7763948601336744
# At random state 42 Testing accuracy is: 0.7676703500385945
#
#
# At random state 43 Training accuracy is: 0.7693992409726812
# At random state 43 Testing accuracy is: 0.7836730527270318
#
#
# At random state 44 Training accuracy is: 0.7766238636438256
# At random state 44 Testing accuracy is: 0.7672559863384537
#
#
# At random state 45 Training accuracy is: 0.7746811680372153
# At random state 45 Testing accuracy is: 0.7720757374991151
#
#
# At random state 46 Training accuracy is: 0.775625494142511
# At random state 46 Testing accuracy is: 0.7699905773329005
#
#
# At random state 47 Training accuracy is: 0.7732530513634627
# At random state 47 Testing accuracy is: 0.7750308802915175
#
#
# At random state 48 Training accuracy is: 0.7766303822454477
# At random state 48 Testing accuracy is: 0.7674693445110601
#
#
# At random state 49 Training accuracy is: 0.7697406851678026
# At random state 49 Testing accuracy is: 0.783086839900395
#
#
# At random state 50 Training accuracy is: 0.7761659426232209
# At random state 50 Testing accuracy is: 0.7683694559182257
#
#
# At random state 51 Training accuracy is: 0.7713238099079525
# At random state 51 Testing accuracy is: 0.7798385955783204
#
#
# At random state 52 Training accuracy is: 0.7797166032203549
# At random state 52 Testing accuracy is: 0.7600698394131993
#
#
# At random state 53 Training accuracy is: 0.7712602480569111
# At random state 53 Testing accuracy is: 0.7781721784159503
#
#
# At random state 54 Training accuracy is: 0.7775675340743763
# At random state 54 Testing accuracy is: 0.7649101167003761
#
#
# At random state 55 Training accuracy is: 0.7806669885043148
# At random state 55 Testing accuracy is: 0.7571102122169053
#
#
# At random state 56 Training accuracy is: 0.7704493429188211
# At random state 56 Testing accuracy is: 0.7815668805801059
#
#
# At random state 57 Training accuracy is: 0.7744597668960495
# At random state 57 Testing accuracy is: 0.7721079872944356
#
#
# At random state 58 Training accuracy is: 0.774182259059602
# At random state 58 Testing accuracy is: 0.7728164805918784
#
#
# At random state 59 Training accuracy is: 0.7724284815433431
# At random state 59 Testing accuracy is: 0.7770544858472539
#
#
# At random state 60 Training accuracy is: 0.7756001889405146
# At random state 60 Testing accuracy is: 0.7693310262240421
#
#
# At random state 61 Training accuracy is: 0.7681213059089533
# At random state 61 Testing accuracy is: 0.7864287674486009
#
#
# At random state 62 Training accuracy is: 0.7740911142195712
# At random state 62 Testing accuracy is: 0.7734994346434677
#
#
# At random state 63 Training accuracy is: 0.7773225655058726
# At random state 63 Testing accuracy is: 0.7663298851946065
#
#
# At random state 64 Training accuracy is: 0.7763031731048977
# At random state 64 Testing accuracy is: 0.7672151168376469
#
#
# At random state 65 Training accuracy is: 0.7773180570825088
# At random state 65 Testing accuracy is: 0.7655024770827139
#
#
# At random state 66 Training accuracy is: 0.773564080104441
# At random state 66 Testing accuracy is: 0.7741826767190899
#
#
# At random state 67 Training accuracy is: 0.7690117788583355
# At random state 67 Testing accuracy is: 0.7860027657270178
#
#
# At random state 68 Training accuracy is: 0.7774786491949794
# At random state 68 Testing accuracy is: 0.7649494229910616
# At random state 69 Training accuracy is: 0.7798498271404057
# At random state 69 Testing accuracy is: 0.7597832982964317
#
#
# At random state 70 Training accuracy is: 0.7749826713858775
# At random state 70 Testing accuracy is: 0.7711880768347072
#
#
# At random state 71 Training accuracy is: 0.7788754680259224
# At random state 71 Testing accuracy is: 0.7611724802139626
#
#
# At random state 72 Training accuracy is: 0.775864821862517
# At random state 72 Testing accuracy is: 0.7689983337446611
#
#
# At random state 73 Training accuracy is: 0.7755976041193107
# At random state 73 Testing accuracy is: 0.7701786277078845
#
#
# At random state 74 Training accuracy is: 0.7726789025662544
# At random state 74 Testing accuracy is: 0.7764756524202914
#
#
# At random state 75 Training accuracy is: 0.7777911567065701
# At random state 75 Testing accuracy is: 0.7646602706957272
#
#
# At random state 76 Training accuracy is: 0.7718726496476724
# At random state 76 Testing accuracy is: 0.777359290498862
#
#
# At random state 77 Training accuracy is: 0.7743455885852004
# At random state 77 Testing accuracy is: 0.7732909109733425
#
#
# At random state 78 Training accuracy is: 0.7696149972242236
# At random state 78 Testing accuracy is: 0.7820446684446669
#
#
# At random state 79 Training accuracy is: 0.7746977956456154
# At random state 79 Testing accuracy is: 0.7718722815618821
#
#
# At random state 80 Training accuracy is: 0.7752842341650727
# At random state 80 Testing accuracy is: 0.7701346887764604
#
#
# At random state 81 Training accuracy is: 0.7740292896761563
# At random state 81 Testing accuracy is: 0.7728819691300858
#
#
# At random state 82 Training accuracy is: 0.7790339413350952
# At random state 82 Testing accuracy is: 0.76083362239174
#
#
# At random state 83 Training accuracy is: 0.7743770073081342
# At random state 83 Testing accuracy is: 0.7734062954610224
#
#
# At random state 84 Training accuracy is: 0.7751985419140449
# At random state 84 Testing accuracy is: 0.7689039552001474
#
#
# At random state 85 Training accuracy is: 0.7741947367872335
# At random state 85 Testing accuracy is: 0.7727366035027032
#
#
# At random state 86 Training accuracy is: 0.7730978383103762
# At random state 86 Testing accuracy is: 0.7757255797202462
#
#
# At random state 87 Training accuracy is: 0.7815949438529984
# At random state 87 Testing accuracy is: 0.7551563925999638
#
#
# At random state 88 Training accuracy is: 0.7742510196380461
# At random state 88 Testing accuracy is: 0.773408941448303
#
#
# At random state 89 Training accuracy is: 0.7728758440197465
# At random state 89 Testing accuracy is: 0.7764219062344435
#
#
# At random state 90 Training accuracy is: 0.7833978766206748
# At random state 90 Testing accuracy is: 0.7515563826047557
#
#
# At random state 91 Training accuracy is: 0.7773676678549024
# At random state 91 Testing accuracy is: 0.7660000680438475
#
#
# At random state 92 Training accuracy is: 0.7680588181497716
# At random state 92 Testing accuracy is: 0.7873902295854883
#
#
# At random state 93 Training accuracy is: 0.7736053895092796
# At random state 93 Testing accuracy is: 0.7744351848739436
#
#
# At random state 94 Training accuracy is: 0.7739817324121303
# At random state 94 Testing accuracy is: 0.7733885746730422
#
#
# At random state 95 Training accuracy is: 0.7730822326135603
# At random state 95 Testing accuracy is: 0.7758237787945079
#
#
# At random state 96 Training accuracy is: 0.7743048228904836
# At random state 96 Testing accuracy is: 0.773469160629581
#
#
# At random state 97 Training accuracy is: 0.7713889086418172
# At random state 97 Testing accuracy is: 0.7793856185305352
#
#
# At random state 98 Training accuracy is: 0.7765836757509381
# At random state 98 Testing accuracy is: 0.7669704784576789
#
#
# At random state 99 Training accuracy is: 0.7855681378026189
# At random state 99 Testing accuracy is: 0.7459896796539981

# %%
# We got the best result at this random state
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=33)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((4825, 24), (2069, 24), (4825,), (2069,))

# %% [markdown]
# ### Different models for Modelling

# %%
LS=Lasso()
RD=Ridge()
KNN=KNeighborsRegressor()
RF=RandomForestRegressor()
ADA=AdaBoostRegressor()
SV=SVR()

# %%
model=[LR,LS,RD,KNN,RF,ADA,SV]

# %%
for i in model:
    print('\n')
    print('******************',i,'*******************')
    print('\n')
    i.fit(x_train,y_train)
    pred=i.predict(x_test)
    pred_t=i.predict(x_train)
    score=i.score(x_train,y_train)
    print('score:',score)
    print('mean absolute error:',mean_absolute_error(y_test,pred))
    print('Root mean squared error:', np.sqrt(mean_squared_error(y_test,pred)))
    print('r2_score:',r2_score(y_test,pred))
    cvs=cross_val_score(i, x, y, cv=4)
    print('Cross Validation Score:',cvs.mean())
# Out:
# ****************** LinearRegression() *******************
#
#
# score: 0.7690521789711124
# mean absolute error: 1.04611950182131
# Root mean squared error: 1.3665420844629743
# r2_score: 0.7852831425207061
# Cross Validation Score: 0.6992590922393775
#
#
# ****************** Lasso() *******************
#
#
# score: 0.6932878954165884
# mean absolute error: 1.2455936127759102
# Root mean squared error: 1.6086831071736154
# r2_score: 0.7024491993875877
# Cross Validation Score: 0.632955180964336
#
#
# ****************** Ridge() *******************
#
#
# score: 0.7690505232276552
# mean absolute error: 1.0461452610199398
# Root mean squared error: 1.3666213713605897
# r2_score: 0.7852582260142001
# Cross Validation Score: 0.6993004769805475
#
#
# ****************** KNeighborsRegressor() *******************
#
#
# score: 0.8433590490206349
# mean absolute error: 1.0164768434010456
# Root mean squared error: 1.3975876718778273
# r2_score: 0.7754162947377297
# Cross Validation Score: -0.8278875530987009
#
#
# ****************** RandomForestRegressor() *******************
#
#
# score: 0.9857150880539304
# mean absolute error: 0.6950794984053401
# Root mean squared error: 0.9321487531751774
# r2_score: 0.9000942311089505
# Cross Validation Score: 0.6617921819229757
#
#
# ****************** AdaBoostRegressor() *******************
#
#
# score: 0.7664030706934314
# mean absolute error: 1.1656798885293131
# Root mean squared error: 1.4422883125456543
# r2_score: 0.7608203152856152
# Cross Validation Score: 0.6533519597105678
#
#
# ****************** SVR() *******************
#
#
# score: -0.00634916108847583
# mean absolute error: 2.389050204531538
# Root mean squared error: 2.958853505195704
# r2_score: -0.006623459591756031
# Cross Validation Score: -0.13702555032533875

# %% [markdown]
# From the above observations, we can see that, best model is Random Forest Regressor is giving the best results with r2 score-90% , accuracy score- 98%, RMSE- 0.90 and MAE-0.69

# %% [markdown]
# ### Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters={'max_features':['auto','sqrt'],'min_samples_split':[5, 10, 15],'min_samples_leaf':[5, 10]}
gcv=GridSearchCV(RF,parameters)

# %%
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [5, 10],
#                          'min_samples_split': [5, 10, 15]})

# %%
#checking the best parameters
gcv.best_params_
# Out:
# {'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5}

# %%
predgcv=gcv.best_estimator_.predict(x_test)

# %%
print('Mean absolute error:',mean_absolute_error(y_test,predgcv))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test,predgcv)))
print('r2_score:',r2_score(y_test,predgcv))
cv_score=cross_val_score(RF,x,y,cv=5)
print('Cross Val Score is:',cv_score.mean())
# Out:
# Mean absolute error: 0.7320058819282198
# Root mean squared error: 0.9813648596386041
# r2_score: 0.8892659647566864
# Cross Val Score is: 0.6688658135293155

# %% [markdown]
# So as we can see that there is improvement in r2 score now comes to 88% with mae=0.73 and rmse =0.98.

# %%
#ploting model results correlation-
plt.figure(figsize=(12,8))
plt.scatter(x=y_test, y=predgcv, color='b')
plt.plot(y_test,y_test,color='r')
plt.xlabel('Actual prices')
plt.ylabel('Predicted prices')
plt.title('Random-Forest-Regressor')
plt.show()

# %% [markdown]
# Here we can see that our model has good fitnessline.

# %% [markdown]
# ### Training Data for Target Model - Next_Tmin

# %%
LR=LinearRegression()
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(m,n,test_size=.33,random_state=i)
    LR.fit(x_train,y_train)
    pred_train=LR.predict(x_train)
    pred_test=LR.predict(x_test)
    print('At random state',i,'Training accuracy is:', r2_score(y_train,pred_train))
    print('At random state',i,'Testing accuracy is:',r2_score(y_test,pred_test))
    print('\n')
# Out:
# At random state 0 Training accuracy is: 0.997256022168863
# At random state 0 Testing accuracy is: 0.9972424641444173
#
#
# At random state 1 Training accuracy is: 0.9972604888979649
# At random state 1 Testing accuracy is: 0.9972193266231467
#
#
# At random state 2 Training accuracy is: 0.9973186523412547
# At random state 2 Testing accuracy is: 0.9971125836087896
#
#
# At random state 3 Training accuracy is: 0.9972719541757068
# At random state 3 Testing accuracy is: 0.9972083585763468
#
#
# At random state 4 Training accuracy is: 0.9973035337205748
# At random state 4 Testing accuracy is: 0.9971357519699577
#
#
# At random state 5 Training accuracy is: 0.9972580322230009
# At random state 5 Testing accuracy is: 0.9972416194705205
#
#
# At random state 6 Training accuracy is: 0.9972949426695564
# At random state 6 Testing accuracy is: 0.9971644069766799
#
#
# At random state 7 Training accuracy is: 0.9972168518795183
# At random state 7 Testing accuracy is: 0.9973219578911906
#
#
# At random state 8 Training accuracy is: 0.9972533251572077
# At random state 8 Testing accuracy is: 0.9972483571730594
#
#
# At random state 9 Training accuracy is: 0.997195015252375
# At random state 9 Testing accuracy is: 0.9973534687015813
#
#
# At random state 10 Training accuracy is: 0.9972185758048119
# At random state 10 Testing accuracy is: 0.9973048628069446
#
#
# At random state 11 Training accuracy is: 0.9972870167199215
# At random state 11 Testing accuracy is: 0.9971817758130701
#
#
# At random state 12 Training accuracy is: 0.997225825099535
# At random state 12 Testing accuracy is: 0.9972951088175301
#
#
# At random state 13 Training accuracy is: 0.997240960346238
# At random state 13 Testing accuracy is: 0.9972661280080629
#
#
# At random state 14 Training accuracy is: 0.9973052337013029
# At random state 14 Testing accuracy is: 0.9971322925125408
#
#
# At random state 15 Training accuracy is: 0.9972482117226135
# At random state 15 Testing accuracy is: 0.9972524648540357
#
#
# At random state 16 Training accuracy is: 0.9972467898127657
# At random state 16 Testing accuracy is: 0.9972528078593308
#
#
# At random state 17 Training accuracy is: 0.9972827155439684
# At random state 17 Testing accuracy is: 0.9971936746027525
#
#
# At random state 18 Training accuracy is: 0.9972152794149188
# At random state 18 Testing accuracy is: 0.9973296912147378
#
#
# At random state 19 Training accuracy is: 0.9972809905646198
# At random state 19 Testing accuracy is: 0.9972008461894292
#
#
# At random state 20 Training accuracy is: 0.9973362717887854
# At random state 20 Testing accuracy is: 0.9970695520921534
#
#
# At random state 21 Training accuracy is: 0.997273295698597
# At random state 21 Testing accuracy is: 0.9972006650189518
#
#
# At random state 22 Training accuracy is: 0.9972873024631436
# At random state 22 Testing accuracy is: 0.997176821685061
#
#
# At random state 23 Training accuracy is: 0.9972406034241655
# At random state 23 Testing accuracy is: 0.9972690575279342
#
#
# At random state 24 Training accuracy is: 0.9972348895104801
# At random state 24 Testing accuracy is: 0.9972910888216432
#
#
# At random state 25 Training accuracy is: 0.9971949189057822
# At random state 25 Testing accuracy is: 0.997371724020354
#
#
# At random state 26 Training accuracy is: 0.99730487662985
# At random state 26 Testing accuracy is: 0.9971434940029688
#
#
# At random state 27 Training accuracy is: 0.9972693896952165
# At random state 27 Testing accuracy is: 0.9972119690353632
#
#
# At random state 28 Training accuracy is: 0.9972616162411122
# At random state 28 Testing accuracy is: 0.9972252700836853
#
#
# At random state 29 Training accuracy is: 0.9972905203851222
# At random state 29 Testing accuracy is: 0.9971759453602058
#
#
# At random state 30 Training accuracy is: 0.9972424709897779
# At random state 30 Testing accuracy is: 0.997275155751683
#
#
# At random state 31 Training accuracy is: 0.997239829096958
# At random state 31 Testing accuracy is: 0.997280717854653
#
#
# At random state 32 Training accuracy is: 0.9973456789647508
# At random state 32 Testing accuracy is: 0.9970641848884388
#
#
# At random state 33 Training accuracy is: 0.9972751892127796
# At random state 33 Testing accuracy is: 0.9972047217566219
#
#
# At random state 34 Training accuracy is: 0.9972062167079123
# At random state 34 Testing accuracy is: 0.9973438128524685
#
#
# At random state 35 Training accuracy is: 0.9972615658209486
# At random state 35 Testing accuracy is: 0.9972298280738455
#
#
# At random state 36 Training accuracy is: 0.9972243338378846
# At random state 36 Testing accuracy is: 0.9973074389523958
#
#
# At random state 37 Training accuracy is: 0.9972322142110832
# At random state 37 Testing accuracy is: 0.9972920585587556
#
#
# At random state 38 Training accuracy is: 0.9973610066134819
# At random state 38 Testing accuracy is: 0.9970308831470438
#
#
# At random state 39 Training accuracy is: 0.9973283360282152
# At random state 39 Testing accuracy is: 0.9970956922108011
#
#
# At random state 40 Training accuracy is: 0.9972624381898706
# At random state 40 Testing accuracy is: 0.9972278719558634
#
#
# At random state 41 Training accuracy is: 0.9972922323306066
# At random state 41 Testing accuracy is: 0.9971623790994514
#
#
# At random state 42 Training accuracy is: 0.9971841182858983
# At random state 42 Testing accuracy is: 0.9973923013399221
#
#
# At random state 43 Training accuracy is: 0.9972716402095351
# At random state 43 Testing accuracy is: 0.9972098423900725
#
#
# At random state 44 Training accuracy is: 0.997248002862346
# At random state 44 Testing accuracy is: 0.997264909432522
#
#
# At random state 45 Training accuracy is: 0.9973065040650596
# At random state 45 Testing accuracy is: 0.9971443355076693
#
#
# At random state 46 Training accuracy is: 0.9973206308997189
# At random state 46 Testing accuracy is: 0.9971050997081689
#
#
# At random state 47 Training accuracy is: 0.9973190632715845
# At random state 47 Testing accuracy is: 0.9971129339366294
#
#
# At random state 48 Training accuracy is: 0.997312118067501
# At random state 48 Testing accuracy is: 0.9971323822941253
#
#
# At random state 49 Training accuracy is: 0.9972323777209386
# At random state 49 Testing accuracy is: 0.9972891275323069
#
#
# At random state 50 Training accuracy is: 0.9973107021348928
# At random state 50 Testing accuracy is: 0.9971306968910363
#
#
# At random state 51 Training accuracy is: 0.9972708699916001
# At random state 51 Testing accuracy is: 0.9972090567706774
#
#
# At random state 52 Training accuracy is: 0.9972105193100819
# At random state 52 Testing accuracy is: 0.9973353500710229
#
#
# At random state 53 Training accuracy is: 0.997174746914315
# At random state 53 Testing accuracy is: 0.9973939899939253
#
#
# At random state 54 Training accuracy is: 0.9971712720682998
# At random state 54 Testing accuracy is: 0.9974120036152287
#
#
# At random state 55 Training accuracy is: 0.9972780783633833
# At random state 55 Testing accuracy is: 0.9971963515605732
#
#
# At random state 56 Training accuracy is: 0.997303047397371
# At random state 56 Testing accuracy is: 0.9971503155951651
#
#
# At random state 57 Training accuracy is: 0.9972924345815085
# At random state 57 Testing accuracy is: 0.9971640669281726
#
#
# At random state 58 Training accuracy is: 0.9971914154734458
# At random state 58 Testing accuracy is: 0.9973853558549859
#
#
# At random state 59 Training accuracy is: 0.9972712909203388
# At random state 59 Testing accuracy is: 0.9972151547940188
#
#
# At random state 60 Training accuracy is: 0.9972761571968292
# At random state 60 Testing accuracy is: 0.9971999122289582
#
#
# At random state 61 Training accuracy is: 0.9972424940382079
# At random state 61 Testing accuracy is: 0.9972630370132404
#
#
# At random state 62 Training accuracy is: 0.9972542066777432
# At random state 62 Testing accuracy is: 0.9972514477591172
#
#
# At random state 63 Training accuracy is: 0.997320784353804
# At random state 63 Testing accuracy is: 0.9971134071623021
#
#
# At random state 64 Training accuracy is: 0.9972161699373798
# At random state 64 Testing accuracy is: 0.9973221421201164
#
#
# At random state 65 Training accuracy is: 0.9973219842779789
# At random state 65 Testing accuracy is: 0.9971003445126206
#
#
# At random state 66 Training accuracy is: 0.9972391936190816
# At random state 66 Testing accuracy is: 0.9972673632881214
#
#
# At random state 67 Training accuracy is: 0.9972201035002233
# At random state 67 Testing accuracy is: 0.9973218967218727
#
#
# At random state 68 Training accuracy is: 0.9972238089330704
# At random state 68 Testing accuracy is: 0.9973156841678499
#
#
# At random state 69 Training accuracy is: 0.997225579052668
# At random state 69 Testing accuracy is: 0.9973088466438589
#
#
# At random state 70 Training accuracy is: 0.99728658971529
# At random state 70 Testing accuracy is: 0.9971864038946703
#
#
# At random state 71 Training accuracy is: 0.9973295007013582
# At random state 71 Testing accuracy is: 0.9970985448603347
#
#
# At random state 72 Training accuracy is: 0.9973020685120195
# At random state 72 Testing accuracy is: 0.9971495298416282
#
#
# At random state 73 Training accuracy is: 0.9972848389447027
# At random state 73 Testing accuracy is: 0.9971841315024995
#
#
# At random state 74 Training accuracy is: 0.997260591184105
# At random state 74 Testing accuracy is: 0.997237594134684
#
#
# At random state 75 Training accuracy is: 0.9972793692867588
# At random state 75 Testing accuracy is: 0.9971884261700799
#
#
# At random state 76 Training accuracy is: 0.9972332717883392
# At random state 76 Testing accuracy is: 0.997292943636759
#
#
# At random state 77 Training accuracy is: 0.9972988687276998
# At random state 77 Testing accuracy is: 0.9971618633457789
#
#
# At random state 78 Training accuracy is: 0.9973367771600554
# At random state 78 Testing accuracy is: 0.9970780153889643
#
#
# At random state 79 Training accuracy is: 0.9972442795050583
# At random state 79 Testing accuracy is: 0.9972602326561707
#
#
# At random state 80 Training accuracy is: 0.9972410113141524
# At random state 80 Testing accuracy is: 0.9972676216028393
#
#
# At random state 81 Training accuracy is: 0.9973757375401651
# At random state 81 Testing accuracy is: 0.9969871739029961
#
#
# At random state 82 Training accuracy is: 0.9972596513421569
# At random state 82 Testing accuracy is: 0.9972275763179775
#
#
# At random state 83 Training accuracy is: 0.9972827939880273
# At random state 83 Testing accuracy is: 0.997189695511582
#
#
# At random state 84 Training accuracy is: 0.9973027376512704
# At random state 84 Testing accuracy is: 0.9971581039082036
#
#
# At random state 85 Training accuracy is: 0.9972872462570376
# At random state 85 Testing accuracy is: 0.9971741444963336
#
#
# At random state 86 Training accuracy is: 0.9973048557323833
# At random state 86 Testing accuracy is: 0.9971296628597984
#
#
# At random state 87 Training accuracy is: 0.9972602959090144
# At random state 87 Testing accuracy is: 0.9972332777950742
#
#
# At random state 88 Training accuracy is: 0.9972324092663452
# At random state 88 Testing accuracy is: 0.9972894148811531
#
#
# At random state 89 Training accuracy is: 0.9972216975079747
# At random state 89 Testing accuracy is: 0.9973036393161326
#
#
# At random state 90 Training accuracy is: 0.9972008007137245
# At random state 90 Testing accuracy is: 0.9973484079016487
#
#
# At random state 91 Training accuracy is: 0.9972416580565729
# At random state 91 Testing accuracy is: 0.9972755633747006
#
#
# At random state 92 Training accuracy is: 0.9972689084087801
# At random state 92 Testing accuracy is: 0.9972158367184635
#
#
# At random state 93 Training accuracy is: 0.9972931473020723
# At random state 93 Testing accuracy is: 0.9971711318576871
#
#
# At random state 94 Training accuracy is: 0.9972421910382087
# At random state 94 Testing accuracy is: 0.997264412513806
#
#
# At random state 95 Training accuracy is: 0.997223487456568
# At random state 95 Testing accuracy is: 0.9972998417590033
#
#
# At random state 96 Training accuracy is: 0.9973726700733232
# At random state 96 Testing accuracy is: 0.9970109532633593
#
#
# At random state 97 Training accuracy is: 0.9972190642577969
# At random state 97 Testing accuracy is: 0.9973084171899553
#
#
# At random state 98 Training accuracy is: 0.9972503317828915
# At random state 98 Testing accuracy is: 0.9972533609039089
#
#
# At random state 99 Training accuracy is: 0.9973443403872649
# At random state 99 Testing accuracy is: 0.9970614634793551

# %% [markdown]
# We are getting best result at 33. So our random state will be 33.

# %%
#we are splitting data at random satate 33
x_train,x_test,y_train,y_test=train_test_split(m,n,test_size=.30,random_state=33)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((4825, 24), (2069, 24), (4825,), (2069,))

# %% [markdown]
# ### Modelling for Different Models.

# %%
LS=Lasso()
RD=Ridge()
KNN=KNeighborsRegressor()
RF=RandomForestRegressor()
ADA=AdaBoostRegressor()
SV=SVR()

# %%
model=[LR,LS,RD,KNN,RF,ADA,SV]

# %%
for i in model:
    print('\n')
    print('******************',i,'*******************')
    print('\n')
    i.fit(x_train,y_train)
    pred=i.predict(x_test)
    pred_t=i.predict(x_train)
    score=i.score(x_train,y_train)
    print('score:',score)
    print('mean absolute error:',mean_absolute_error(y_test,pred))
    print('Root mean squared error:', np.sqrt(mean_squared_error(y_test,pred)))
    print('r2_score:',r2_score(y_test,pred))
    cvs=cross_val_score(i, m, n, cv=4)
    print('Cross Validation Score:',cvs.mean())
# Out:
# ****************** LinearRegression() *******************
#
#
# score: 0.9972810463707676
# mean absolute error: 0.09003471366527986
# Root mean squared error: 0.12723059679730706
# r2_score: 0.9971937765555503
# Cross Validation Score: 0.9964376858987035
#
#
# ****************** Lasso() *******************
#
#
# score: 0.8099664878408388
# mean absolute error: 0.8348493461368501
# Root mean squared error: 1.0508398130289796
# r2_score: 0.8085690489683253
# Cross Validation Score: 0.7861684622852249
#
#
# ****************** Ridge() *******************
#
#
# score: 0.9972788280952161
# mean absolute error: 0.09005791218494977
# Root mean squared error: 0.1273873117144961
# r2_score: 0.9971868592269969
# Cross Validation Score: 0.9964418622222361
#
#
# ****************** KNeighborsRegressor() *******************
#
#
# score: 0.9368797099082977
# mean absolute error: 0.5547423895038643
# Root mean squared error: 0.7239517519577134
# r2_score: 0.9091430054268752
# Cross Validation Score: 0.7489606698489505
#
#
# ****************** RandomForestRegressor() *******************
#
#
# score: 0.999997314503546
# mean absolute error: 0.0013305944901136357
# Root mean squared error: 0.025521501279304883
# r2_score: 0.9998870850216679
# Cross Validation Score: 0.9999247492638175
#
#
# ****************** AdaBoostRegressor() *******************
#
#
# score: 0.9931054242364726
# mean absolute error: 0.15643975619199355
# Root mean squared error: 0.20041799372777563
# r2_score: 0.9930367411365963
# Cross Validation Score: 0.9924318117546209
#
#
# ****************** SVR() *******************
#
#
# score: 0.9971792418060956
# mean absolute error: 0.11925916820519085
# Root mean squared error: 0.200643617267985
# r2_score: 0.9930210543270688
# Cross Validation Score: 0.9671000861943415

# %% [markdown]
# From the above observations, we can see that, best model is Random Forest Regressor is giving the best results with r2 score-99% , accuracy score- 99%, RMSE- 0.20 and MAE-0.19

# %% [markdown]
# ### Hyper Parameter Tuning for the model

# %%
from sklearn.model_selection import GridSearchCV

parameters={'max_features':['auto','sqrt'],'min_samples_split':[5, 10, 15],'min_samples_leaf':[5, 10]}
gcv=GridSearchCV(RF,parameters)

# %%
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [5, 10],
#                          'min_samples_split': [5, 10, 15]})

# %%
#checking the best parameters
gcv.best_params_
# Out:
# {'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 10}

# %%
predgcv=gcv.best_estimator_.predict(x_test)

# %%
print('Mean absolute error:',mean_absolute_error(y_test,predgcv))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test,predgcv)))
print('r2_score:',r2_score(y_test,predgcv))
cv_score=cross_val_score(RF,m,n,cv=5)
print('Cross Val Score is:',cv_score.mean())
# Out:
# Mean absolute error: 0.0016958315020204084
# Root mean squared error: 0.016820407057327937
# r2_score: 0.9999493247464066
# Cross Val Score is: 0.9999194478829649

# %% [markdown]
# So,as we can see that there is improvement in r2 score now comes to 99% with mae=0.016 and rmse =0.016.

# %%
#ploting model results correlation-
plt.figure(figsize=(12,8))
plt.scatter(x=y_test, y=predgcv, color='b')
plt.plot(y_test,y_test,color='r')
plt.xlabel('Actual prices')
plt.ylabel('Predicted prices')
plt.title('Random-Forest-Regressor')
plt.show()

# %% [markdown]
# ### Here we can say that we have achieved almost perfect model with 99% accuracy.
